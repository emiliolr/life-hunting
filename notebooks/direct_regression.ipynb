# %% [markdown]
# # Setup

# %%
import json
import os
import sys
import pickle
import warnings

sys.path.append('..')

import pandas as pd
import numpy as np

from flaml import AutoML

from utils import read_csv_non_utf, preprocess_data, ratios_to_DI_cats, get_train_test_split
from performance_reports import get_regression_report, get_classification_report

# %%
# Loading in general configuration
with open('../config.json', 'r') as f:
    config = json.load(f)

# Getting filepaths
gdrive_fp = config['gdrive_path']
LIFE_fp = config['LIFE_folder']
dataset_fp = config['datasets_path']
benitez_lopez2019 = config['indiv_data_paths']['benitez_lopez2019']

data_path = os.path.join(gdrive_fp, LIFE_fp, dataset_fp, benitez_lopez2019)

# %%
# Reading in data as a pandas dataframe
ben_lop2019 = read_csv_non_utf(data_path)

# %%
# Getting the shared basic train/test split
train_size = 0.7
idxs = get_train_test_split(len(ben_lop2019), train_size = train_size)

# Pre-processing data
pp_data = preprocess_data(ben_lop2019, include_indicators = False, standardize = True, log_trans_cont = False,
                          polynomial_features = 0, train_test_idxs = idxs)

#  splitting the actual dataset into train/test sets
train_data, test_data = pp_data.loc[idxs['train']], pp_data.loc[idxs['test']]

#  putting into the format that FLAML wants
X_train, X_test = train_data.drop(columns = 'ratio').values, test_data.drop(columns = 'ratio').values
y_train, y_test = train_data['ratio'].values, test_data['ratio'].values

# %% [markdown]
# # AutoML
#
# I am using Microsoft's [`flaml`](https://github.com/microsoft/FLAML) for AutoML, which supports a range of models for regression:
# - [Light Gradient Boosting Machine (LGBM)](https://github.com/microsoft/LightGBM),
# - [Extreme Gradient Boosting (XGBoost)](https://github.com/dmlc/xgboost),
# - [Random Forest (RF)](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor),
# - [Extra Trees](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesRegressor.html),
# - [Histogram Gradient Boosting](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html#sklearn.ensemble.HistGradientBoostingRegressor),
# - [Categorical Boosting (CatBoost)](https://github.com/catboost/catboost),
# - [$k$-Nearest Neighbors ($k$-NN)](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html).
#
# Noticeably, linear models and neural networks are missing from the mix, but we may be able to use `flaml` to perform [efficient hyperparameter tuning](https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML#guidelines-on-tuning-a-custom-estimator) on these using `sklearn` or `PyTorch` implementations.

# %%
# Initialize the auto ML instance
automl = AutoML()

# Specify paramaters
automl_settings = {
    'time_budget' : 60,  # in seconds
    'metric' : 'mae',
    'task' : 'regression',
    'log_file_name' : 'mammals_direct_regression.log'
}

# Train with labeled input data
automl.fit(X_train = X_train, y_train = y_train, **automl_settings)
# Out:
# [flaml.automl.logger: 05-20 16:35:13] {1680} INFO - task = regression
# [flaml.automl.logger: 05-20 16:35:13] {1691} INFO - Evaluation method: cv
# [flaml.automl.logger: 05-20 16:35:13] {1789} INFO - Minimizing error metric: mae
# [flaml.automl.logger: 05-20 16:35:13] {1901} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 05-20 16:35:13] {2219} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:14] {2345} INFO - Estimated sufficient time budget=6911s. Estimated necessary time budget=49s.
# [flaml.automl.logger: 05-20 16:35:14] {2392} INFO -  at 0.7s,	estimator lgbm's best error=0.9137,	best estimator lgbm's best error=0.9137
# [flaml.automl.logger: 05-20 16:35:14] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:14] {2392} INFO -  at 1.3s,	estimator lgbm's best error=0.9137,	best estimator lgbm's best error=0.9137
# [flaml.automl.logger: 05-20 16:35:14] {2219} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:14] {2392} INFO -  at 1.4s,	estimator lgbm's best error=0.9118,	best estimator lgbm's best error=0.9118
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 1.6s,	estimator lgbm's best error=0.9118,	best estimator lgbm's best error=0.9118
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 1.6s,	estimator lgbm's best error=0.9115,	best estimator lgbm's best error=0.9115
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 1.7s,	estimator lgbm's best error=0.9108,	best estimator lgbm's best error=0.9108
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 1.8s,	estimator lgbm's best error=0.9108,	best estimator lgbm's best error=0.9108
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 1.8s,	estimator lgbm's best error=0.9054,	best estimator lgbm's best error=0.9054
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 1.9s,	estimator lgbm's best error=0.9054,	best estimator lgbm's best error=0.9054
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 1.9s,	estimator lgbm's best error=0.9054,	best estimator lgbm's best error=0.9054
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 2.0s,	estimator lgbm's best error=0.8679,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 2.1s,	estimator lgbm's best error=0.8679,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:15] {2392} INFO -  at 2.1s,	estimator lgbm's best error=0.8679,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:15] {2219} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:16] {2392} INFO -  at 2.9s,	estimator lgbm's best error=0.8679,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:16] {2219} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:16] {2392} INFO -  at 3.0s,	estimator lgbm's best error=0.8679,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:16] {2219} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:16] {2392} INFO -  at 3.2s,	estimator lgbm's best error=0.8679,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:16] {2219} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:16] {2392} INFO -  at 3.3s,	estimator xgboost's best error=0.9124,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:16] {2219} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:16] {2392} INFO -  at 3.4s,	estimator xgboost's best error=0.9124,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:16] {2219} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:16] {2392} INFO -  at 3.4s,	estimator xgboost's best error=0.9124,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:16] {2219} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:17] {2392} INFO -  at 3.5s,	estimator xgboost's best error=0.9124,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:17] {2219} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:17] {2392} INFO -  at 3.6s,	estimator lgbm's best error=0.8679,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:17] {2219} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:17] {2392} INFO -  at 3.7s,	estimator xgboost's best error=0.9124,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:17] {2219} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:17] {2392} INFO -  at 3.8s,	estimator xgboost's best error=0.9120,	best estimator lgbm's best error=0.8679
# [flaml.automl.logger: 05-20 16:35:17] {2219} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:17] {2392} INFO -  at 3.9s,	estimator lgbm's best error=0.8605,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:17] {2219} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 05-20 16:35:17] {2392} INFO -  at 4.2s,	estimator extra_tree's best error=0.9236,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:17] {2219} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 05-20 16:35:17] {2392} INFO -  at 4.4s,	estimator extra_tree's best error=0.9236,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:17] {2219} INFO - iteration 26, current learner extra_tree
# [flaml.automl.logger: 05-20 16:35:18] {2392} INFO -  at 4.7s,	estimator extra_tree's best error=0.9236,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:18] {2219} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 05-20 16:35:18] {2392} INFO -  at 5.0s,	estimator extra_tree's best error=0.9236,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:18] {2219} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 05-20 16:35:18] {2392} INFO -  at 5.2s,	estimator extra_tree's best error=0.9219,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:18] {2219} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:18] {2392} INFO -  at 5.3s,	estimator lgbm's best error=0.8605,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:18] {2219} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:18] {2392} INFO -  at 5.4s,	estimator lgbm's best error=0.8605,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:18] {2219} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:19] {2392} INFO -  at 5.6s,	estimator lgbm's best error=0.8605,	best estimator lgbm's best error=0.8605
# [flaml.automl.logger: 05-20 16:35:19] {2219} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:19] {2392} INFO -  at 5.8s,	estimator lgbm's best error=0.8476,	best estimator lgbm's best error=0.8476
# [flaml.automl.logger: 05-20 16:35:19] {2219} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:19] {2392} INFO -  at 5.9s,	estimator lgbm's best error=0.8476,	best estimator lgbm's best error=0.8476
# [flaml.automl.logger: 05-20 16:35:19] {2219} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:19] {2392} INFO -  at 6.0s,	estimator lgbm's best error=0.8476,	best estimator lgbm's best error=0.8476
# [flaml.automl.logger: 05-20 16:35:19] {2219} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:19] {2392} INFO -  at 6.1s,	estimator lgbm's best error=0.8476,	best estimator lgbm's best error=0.8476
# [flaml.automl.logger: 05-20 16:35:19] {2219} INFO - iteration 36, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:19] {2392} INFO -  at 6.3s,	estimator lgbm's best error=0.8476,	best estimator lgbm's best error=0.8476
# [flaml.automl.logger: 05-20 16:35:19] {2219} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:19] {2392} INFO -  at 6.4s,	estimator lgbm's best error=0.8476,	best estimator lgbm's best error=0.8476
# [flaml.automl.logger: 05-20 16:35:19] {2219} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:20] {2392} INFO -  at 6.6s,	estimator lgbm's best error=0.8179,	best estimator lgbm's best error=0.8179
# [flaml.automl.logger: 05-20 16:35:20] {2219} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:20] {2392} INFO -  at 7.2s,	estimator lgbm's best error=0.8179,	best estimator lgbm's best error=0.8179
# [flaml.automl.logger: 05-20 16:35:20] {2219} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:21] {2392} INFO -  at 7.8s,	estimator lgbm's best error=0.8179,	best estimator lgbm's best error=0.8179
# [flaml.automl.logger: 05-20 16:35:21] {2219} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:21] {2392} INFO -  at 8.0s,	estimator lgbm's best error=0.8044,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:21] {2219} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:21] {2392} INFO -  at 8.2s,	estimator lgbm's best error=0.8044,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:21] {2219} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:21] {2392} INFO -  at 8.4s,	estimator xgboost's best error=0.9034,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:21] {2219} INFO - iteration 44, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:22] {2392} INFO -  at 8.5s,	estimator xgboost's best error=0.9034,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:22] {2219} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:22] {2392} INFO -  at 8.9s,	estimator lgbm's best error=0.8044,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:22] {2219} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:22] {2392} INFO -  at 9.1s,	estimator lgbm's best error=0.8044,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:22] {2219} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:23] {2392} INFO -  at 9.7s,	estimator lgbm's best error=0.8044,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:23] {2219} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 05-20 16:35:23] {2392} INFO -  at 9.9s,	estimator rf's best error=0.9047,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:23] {2219} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 05-20 16:35:23] {2392} INFO -  at 10.1s,	estimator rf's best error=0.9047,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:23] {2219} INFO - iteration 50, current learner rf
# [flaml.automl.logger: 05-20 16:35:23] {2392} INFO -  at 10.4s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:23] {2219} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:24] {2392} INFO -  at 10.5s,	estimator lgbm's best error=0.8044,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:24] {2219} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:24] {2392} INFO -  at 10.7s,	estimator lgbm's best error=0.8044,	best estimator lgbm's best error=0.8044
# [flaml.automl.logger: 05-20 16:35:24] {2219} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:24] {2392} INFO -  at 10.9s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:24] {2219} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:25] {2392} INFO -  at 12.1s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:25] {2219} INFO - iteration 55, current learner rf
# [flaml.automl.logger: 05-20 16:35:26] {2392} INFO -  at 12.4s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:26] {2219} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:26] {2392} INFO -  at 12.5s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:26] {2219} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:26] {2392} INFO -  at 12.6s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:26] {2219} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:26] {2392} INFO -  at 13.3s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:26] {2219} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:27] {2392} INFO -  at 13.8s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:27] {2219} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 05-20 16:35:27] {2392} INFO -  at 14.1s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:27] {2219} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:27] {2392} INFO -  at 14.2s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:27] {2219} INFO - iteration 62, current learner rf
# [flaml.automl.logger: 05-20 16:35:28] {2392} INFO -  at 14.5s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:28] {2219} INFO - iteration 63, current learner rf
# [flaml.automl.logger: 05-20 16:35:28] {2392} INFO -  at 14.8s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:28] {2219} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:28] {2392} INFO -  at 14.9s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:28] {2219} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:29] {2392} INFO -  at 15.6s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:29] {2219} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:29] {2392} INFO -  at 15.7s,	estimator xgboost's best error=0.9034,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:29] {2219} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:29] {2392} INFO -  at 15.8s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:29] {2219} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:30] {2392} INFO -  at 16.5s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:30] {2219} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:30] {2392} INFO -  at 16.6s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:30] {2219} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 05-20 16:35:30] {2392} INFO -  at 17.0s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:30] {2219} INFO - iteration 71, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:31] {2392} INFO -  at 17.7s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:31] {2219} INFO - iteration 72, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:31] {2392} INFO -  at 17.8s,	estimator xgboost's best error=0.8590,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:31] {2219} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:31] {2392} INFO -  at 17.9s,	estimator xgboost's best error=0.8590,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:31] {2219} INFO - iteration 74, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:31] {2392} INFO -  at 18.0s,	estimator xgboost's best error=0.8524,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:31] {2219} INFO - iteration 75, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:31] {2392} INFO -  at 18.4s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:31] {2219} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:32] {2392} INFO -  at 18.5s,	estimator lgbm's best error=0.8037,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:32] {2219} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:32] {2392} INFO -  at 18.6s,	estimator xgboost's best error=0.8524,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:32] {2219} INFO - iteration 78, current learner rf
# [flaml.automl.logger: 05-20 16:35:32] {2392} INFO -  at 18.8s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8037
# [flaml.automl.logger: 05-20 16:35:32] {2219} INFO - iteration 79, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:32] {2392} INFO -  at 19.2s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:32] {2219} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:32] {2392} INFO -  at 19.3s,	estimator xgboost's best error=0.8524,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:32] {2219} INFO - iteration 81, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:32] {2392} INFO -  at 19.4s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:32] {2219} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:33] {2392} INFO -  at 19.5s,	estimator xgboost's best error=0.8524,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:33] {2219} INFO - iteration 83, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:33] {2392} INFO -  at 19.6s,	estimator xgboost's best error=0.8524,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:33] {2219} INFO - iteration 84, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:33] {2392} INFO -  at 19.7s,	estimator xgboost's best error=0.8501,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:33] {2219} INFO - iteration 85, current learner rf
# [flaml.automl.logger: 05-20 16:35:33] {2392} INFO -  at 19.9s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:33] {2219} INFO - iteration 86, current learner rf
# [flaml.automl.logger: 05-20 16:35:33] {2392} INFO -  at 20.3s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:33] {2219} INFO - iteration 87, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:34] {2392} INFO -  at 20.7s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:34] {2219} INFO - iteration 88, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:34] {2392} INFO -  at 21.1s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:34] {2219} INFO - iteration 89, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:34] {2392} INFO -  at 21.2s,	estimator xgboost's best error=0.8501,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:34] {2219} INFO - iteration 90, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:35] {2392} INFO -  at 21.7s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:35] {2219} INFO - iteration 91, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:35] {2392} INFO -  at 22.0s,	estimator xgboost's best error=0.8481,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:35] {2219} INFO - iteration 92, current learner rf
# [flaml.automl.logger: 05-20 16:35:35] {2392} INFO -  at 22.1s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:35] {2219} INFO - iteration 93, current learner rf
# [flaml.automl.logger: 05-20 16:35:36] {2392} INFO -  at 22.4s,	estimator rf's best error=0.8839,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:36] {2219} INFO - iteration 94, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:36] {2392} INFO -  at 22.9s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:36] {2219} INFO - iteration 95, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:36] {2392} INFO -  at 23.0s,	estimator xgboost's best error=0.8481,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:36] {2219} INFO - iteration 96, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:36] {2392} INFO -  at 23.2s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:36] {2219} INFO - iteration 97, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:38] {2392} INFO -  at 25.1s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:38] {2219} INFO - iteration 98, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:41] {2392} INFO -  at 27.6s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:41] {2219} INFO - iteration 99, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:41] {2392} INFO -  at 28.1s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:41] {2219} INFO - iteration 100, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:42] {2392} INFO -  at 28.6s,	estimator xgboost's best error=0.8057,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:42] {2219} INFO - iteration 101, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:42] {2392} INFO -  at 28.9s,	estimator xgboost's best error=0.8057,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:42] {2219} INFO - iteration 102, current learner lgbm
# [flaml.automl.logger: 05-20 16:35:43] {2392} INFO -  at 29.5s,	estimator lgbm's best error=0.8022,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:43] {2219} INFO - iteration 103, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:43] {2392} INFO -  at 29.9s,	estimator xgboost's best error=0.8057,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:43] {2219} INFO - iteration 104, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:43] {2392} INFO -  at 30.4s,	estimator xgboost's best error=0.8057,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:43] {2219} INFO - iteration 105, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:44] {2392} INFO -  at 30.7s,	estimator xgboost's best error=0.8057,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:44] {2219} INFO - iteration 106, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:44] {2392} INFO -  at 30.8s,	estimator xgboost's best error=0.8057,	best estimator lgbm's best error=0.8022
# [flaml.automl.logger: 05-20 16:35:44] {2219} INFO - iteration 107, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:47] {2392} INFO -  at 33.9s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:35:47] {2219} INFO - iteration 108, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:48] {2392} INFO -  at 35.2s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:35:48] {2219} INFO - iteration 109, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:50] {2392} INFO -  at 37.4s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:35:50] {2219} INFO - iteration 110, current learner rf
# [flaml.automl.logger: 05-20 16:35:51] {2392} INFO -  at 37.7s,	estimator rf's best error=0.8839,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:35:51] {2219} INFO - iteration 111, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:51] {2392} INFO -  at 38.1s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:35:51] {2219} INFO - iteration 112, current learner xgboost
# [flaml.automl.logger: 05-20 16:35:59] {2392} INFO -  at 46.4s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:35:59] {2219} INFO - iteration 113, current learner extra_tree
# [flaml.automl.logger: 05-20 16:36:00] {2392} INFO -  at 46.6s,	estimator extra_tree's best error=0.9219,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:00] {2219} INFO - iteration 114, current learner rf
# [flaml.automl.logger: 05-20 16:36:00] {2392} INFO -  at 46.9s,	estimator rf's best error=0.8839,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:00] {2219} INFO - iteration 115, current learner rf
# [flaml.automl.logger: 05-20 16:36:00] {2392} INFO -  at 47.1s,	estimator rf's best error=0.8839,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:00] {2219} INFO - iteration 116, current learner xgboost
# [flaml.automl.logger: 05-20 16:36:01] {2392} INFO -  at 48.0s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:01] {2219} INFO - iteration 117, current learner xgboost
# [flaml.automl.logger: 05-20 16:36:02] {2392} INFO -  at 48.8s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:02] {2219} INFO - iteration 118, current learner rf
# [flaml.automl.logger: 05-20 16:36:02] {2392} INFO -  at 49.2s,	estimator rf's best error=0.8839,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:02] {2219} INFO - iteration 119, current learner xgboost
# [flaml.automl.logger: 05-20 16:36:03] {2392} INFO -  at 50.4s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:03] {2219} INFO - iteration 120, current learner xgboost
# [flaml.automl.logger: 05-20 16:36:05] {2392} INFO -  at 51.9s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:05] {2219} INFO - iteration 121, current learner xgboost
# [flaml.automl.logger: 05-20 16:36:12] {2392} INFO -  at 58.8s,	estimator xgboost's best error=0.7822,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:12] {2219} INFO - iteration 122, current learner xgb_limitdepth
# [flaml.automl.logger: 05-20 16:36:12] {2392} INFO -  at 58.9s,	estimator xgb_limitdepth's best error=0.8579,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:12] {2219} INFO - iteration 123, current learner xgb_limitdepth
# [flaml.automl.logger: 05-20 16:36:12] {2392} INFO -  at 59.0s,	estimator xgb_limitdepth's best error=0.8357,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:12] {2219} INFO - iteration 124, current learner xgb_limitdepth
# [flaml.automl.logger: 05-20 16:36:12] {2392} INFO -  at 59.2s,	estimator xgb_limitdepth's best error=0.8357,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:12] {2219} INFO - iteration 125, current learner rf
# [flaml.automl.logger: 05-20 16:36:13] {2392} INFO -  at 59.4s,	estimator rf's best error=0.8839,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:13] {2219} INFO - iteration 126, current learner extra_tree
# [flaml.automl.logger: 05-20 16:36:13] {2392} INFO -  at 59.7s,	estimator extra_tree's best error=0.9152,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:13] {2219} INFO - iteration 127, current learner extra_tree
# [flaml.automl.logger: 05-20 16:36:13] {2392} INFO -  at 60.0s,	estimator extra_tree's best error=0.9152,	best estimator xgboost's best error=0.7822
# [flaml.automl.logger: 05-20 16:36:13] {2628} INFO - retrain xgboost for 0.3s
# [flaml.automl.logger: 05-20 16:36:13] {2631} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.6142101930678966, colsample_bynode=None,
#              colsample_bytree=0.8198466716884618, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=0.04310643162055607,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=149,
#              min_child_weight=0.08787474752024925, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=65,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 05-20 16:36:13] {1931} INFO - fit succeeded
# [flaml.automl.logger: 05-20 16:36:13] {1932} INFO - Time taken to find the best model: 33.926581144332886

# %%
# Getting regression and classification true vs. predicted
pred_ratios = automl.predict(X_test)
test_ratios = y_test

pred_DI_cats = ratios_to_DI_cats(pred_ratios)
true_DI_cats = ratios_to_DI_cats(test_ratios)

# Getting classification and regression reports
print('CLASSIFICATION PERFORMANCE')
print('--------------------------')
get_classification_report(true_DI_cats, pred_DI_cats, printout = True)
print()

print('REGRESSION PERFORMANCE')
print('----------------------')
get_regression_report(test_ratios, pred_ratios, printout = True)
# Out:
# CLASSIFICATION PERFORMANCE
# --------------------------
#               precision    recall  f1-score   support
#
#          low       0.73      0.76      0.75       560
#       medium       0.31      0.61      0.41       207
#         high       0.00      0.00      0.00       218
#
#     accuracy                           0.56       985
#    macro avg       0.35      0.46      0.39       985
# weighted avg       0.48      0.56      0.51       985
#
# Balanced accuracy: 45.53%
# /Users/emiliolr/miniforge3/envs/life-hunting/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/emiliolr/miniforge3/envs/life-hunting/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/emiliolr/miniforge3/envs/life-hunting/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# REGRESSION PERFORMANCE
# ----------------------
# Mean absolute error: 0.902
# Median absolute error: 0.319
# Root mean squared error: 3.228
# Root median squared error: 0.319
